# %%
# loading usefull packages and functions

import numpy as np
import h5py
from matplotlib import pyplot as plt
import scipy.sparse as sp

from connalysis.network import classic as nxc
from connalysis.network import topology as nxt
from connalysis import randomization
from connalysis.network import topology
#from conntility import circuit_model
import conntility as conn
#from conntility import ConnectivityMatrix

# %%
root = "/Users/natali_obi_account/Desktop/OBI/HUMAN_CORTEX/PAPERS_ON_GOING/CONNECTIVITY_PAPER/code/conn_matrix_OBI/"

#conn_mat_file = "hcrd_structural_circuit/structural/connectivity_matrix.h5"
#conn_mat = conn.ConnectivityMatrix.from_h5(f"{root}{conn_mat_file}", group_name="instance1")

#conn_mat_file = "HO1_circuit/HO1/connectivity_matrix.h5"
#conn_mat = conn.ConnectivityMatrix.from_h5(f"{root}{conn_mat_file}", group_name="compressed")

conn_mat_file = "microns_circuit/microns/connectivity_matrix.h5"
conn_mat = conn.ConnectivityMatrix.from_h5(f"{root}{conn_mat_file}", group_name="condensed")


#mat = ConnectivityMatrix.from_h5(fn, group_name="matrices")
#mat.to_h5(fn_out, group_name="full_matrix")

# %%
adj_conn_mat = conn_mat.matrix

print('number of edges: ', adj_conn_mat.nnz)
print('number of touches: ', adj_conn_mat.sum())
print('number of nodes: ', adj_conn_mat.shape[0])
# Out:
# number of edges:  9005438
# number of touches:  13500999
# number of nodes:  71981
